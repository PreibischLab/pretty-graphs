# %%
# want to see the images inline
# %matplotlib inline

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from scipy.stats import gamma
from scipy.optimize import curve_fit
from scipy import special

from configparser import ConfigParser, ExtendedInterpolation

import utils as utils

from tqdm import tqdm_notebook as tqdm

# %%
# read config file 
config = ConfigParser(interpolation=ExtendedInterpolation())
config.read('config.ini')
# Out:
# ['config.ini']

# %%
TYPES = ['Pha4.ex', 'ama1.ex', 'dpy23.ex', 'mdh1.ex', 'sdc2.ex', 'wdr5.2.ex']
#  'dpy23.int', 'sdc2.int',

# %%
FOLDER = config.get('main', 'ROOTFOLDER')
DB_FILENAME = config.get('main', 'DB_FILENAME')
TYPE = config.get('main', 'TYPE')
COLOR = config.get('main', 'COLOR')
MAKE_IMAGES = config.getboolean('main', 'MAKE_IMAGES')

# %%
# some const params for all graphs
num_bins = 100
# graph [xmin, xmax]
xmin = -0.2
xmax = 3.2
binwidth = (xmax - xmin)/(num_bins - 1)

bins = np.arange(xmin, xmax + binwidth, binwidth)
print ('bins: ', bins.shape)
# Out:
# bins:  (100,)

# %%
# important indices
type_columns = ['c0_type', 'c1_type', 'c2_type']
stain_prefix = np.array([['C0-', 'C1-', 'C2-', 'C3-', 'C4-']])
filename_column = 'cropped_image_file'

# %%
# read the db and parse images that we want to process
df_path = os.path.join(FOLDER, 'smFISH-database', DB_FILENAME)
df = pd.read_csv(df_path, 
                 sep=',', 
                )

# %%
# TODO: maybe it is necessary to fill in other values here, too
# fix missing entries in the colmns that we are planning to use 
df['cropped_image_file'].fillna('', inplace=True)
df['c0_type'].fillna('', inplace=True)
df['c1_type'].fillna('', inplace=True)
df['c2_type'].fillna('', inplace=True)

# %%
dff = df.copy() # df[df['cropped_image_file'].apply(lambda x: x.startswith(EXPERIMENT))]
# dff = df[df['cropped_image_file'].apply(lambda x: x.startswith(EXPERIMENT))]

# %%
dff
# Out:
#        c0        c1        c2   c3    c4  c0_lambda  c1_lambda  c2_lambda  \
# 0     Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 1     Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 2     Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 3     Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 4     Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 5     Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 6     Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 7     Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 8     Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 9     Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 10    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 11    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 12    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 13    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 14    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 15    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 16    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 17    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 18    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 19    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 20    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 21    Cy5   mCherry  GoldFISH  GFP  DAPI      670.0      610.0      566.0
# 22    Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 23    Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 24    Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 25    Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 26    Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 27    Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 28    Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 29    Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# ...   ...       ...       ...  ...   ...        ...        ...        ...
# 6874  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6875  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6876  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6877  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6878  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6879  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6880  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6881  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6882  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6883  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6884  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6885  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6886  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6887  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6888  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6889  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6890  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6891  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6892  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6893  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6894  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6895  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6896  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6897  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6898  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6899  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6900  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6901  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6902  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
# 6903  Cy5  GoldFISH   mCherry  GFP  DAPI      670.0      566.0      610.0
#
#       c3_lambda  c4_lambda  ... #c0_smfish_adj #c1_smfish_adj #c2_smfish_adj  \
# 0         507.0      461.0  ...        1735.83          -1.00        1408.86
# 1         507.0      461.0  ...         537.07         838.14          -1.00
# 2         507.0      461.0  ...        1296.55         323.36          -1.00
# 3         507.0      461.0  ...        1681.77        3289.43          -1.00
# 4         507.0      461.0  ...          92.80        1740.47          -1.00
# 6903            0.0     -1.0          -1.0             -1.0          91.0
#
#        tx  tx_desc
# 0    -1.0      NaN
# 1    -1.0      NaN
# 2    -1.0      NaN
# 3    -1.0      NaN
# 4    -1.0      NaN
# 5    -1.0      NaN
# 6    -1.0      NaN
# 7    -1.0      NaN
# 8    -1.0      NaN
# 9    -1.0      NaN
# 10   -1.0      NaN
# 11   -1.0      NaN
# 12   -1.0      NaN
# 13   -1.0      NaN
# 14   -1.0      NaN
# 15   -1.0      NaN
# 16   -1.0      NaN
# 17   -1.0      NaN
# 18   -1.0      NaN
# 19   -1.0      NaN
# 20   -1.0      NaN
# 21   -1.0      NaN
# 22   -1.0      NaN
# 23   -1.0      NaN
# 24   -1.0      NaN
# 25   -1.0      NaN
# 26   -1.0      NaN
# 27   -1.0      NaN
# 28   -1.0      NaN
# 29   -1.0      NaN
# ...   ...      ...
# 6874 -1.0      NaN
# 6875 -1.0      NaN
# 6876 -1.0      NaN
# 6877 -1.0      NaN
# 6878 -1.0      NaN
# 6879 -1.0      NaN
# 6880 -1.0      NaN
# 6881 -1.0      NaN
# 6882 -1.0      NaN
# 6883 -1.0      NaN
# 6884 -1.0      NaN
# 6885 -1.0      NaN
# 6886 -1.0      NaN
# 6887 -1.0      NaN
# 6888 -1.0      NaN
# 6889 -1.0      NaN
# 6890 -1.0      NaN
# 6891 -1.0      NaN
# 6892 -1.0      NaN
# 6893 -1.0      NaN
# 6894 -1.0      NaN
# 6895 -1.0      NaN
# 6896 -1.0      NaN
# 6897 -1.0      NaN
# 6898 -1.0      NaN
# 6899 -1.0      NaN
# 6900 -1.0      NaN
# 6901 -1.0      NaN
# 6902 -1.0      NaN
# 6903 -1.0      NaN
#
# [6904 rows x 43 columns]

# %%
# seems to be working
row, col = np.where(dff[type_columns].applymap(lambda x: x in TYPES))
n_samples = dff.shape[0]
new_prefix = np.repeat(stain_prefix, n_samples, axis=0)[row, col]
new_filename = dff[filename_column].values[row]
full_filenames = ["{}{}".format(a_, b_[:-4]) for a_, b_ in zip(new_prefix, new_filename)]

# %%
dataset = []
pbar = tqdm(total=len(full_filenames))
for ff in full_filenames: 
    tmp = os.path.join(FOLDER, "csv", ff + ".csv")
    dataset.append(tmp)
    pbar.update(1)
pbar.close()
# Out:
# HBox(children=(IntProgress(value=0, max=13399), HTML(value='')))

# %%
len(full_filenames)
# Out:
# 13399

# %%
# center_path = os.path.join(FOLDER, "centers", "all-centers.csv")

# %%
# have to perform this step multiple times and choose the best one 
# perform n_fits with different initial parameters
# n_fits = 10

center_set = {}

print(f'Processing: {len(dataset)} files') 

# actual plotting 
pbar = tqdm(total=len(dataset))
for d in dataset:    
    pbar.update(1) 
    if(not os.path.exists(d)):
        continue
        
    try:
        # computation
        
        # load the data and scale it accordingly
        I = utils.load_data(d, skiprows_=0)
        
        # calculate the params for gauss fit
        binned_values, real_bins = np.histogram(I, bins)
        use_median = np.median(I)
        # inititally there was use_median/2 
        fit_alpha, fit_loc, fit_beta = gamma.fit(I, 
                                                 loc=use_median/2, 
                                                 scale=1/np.max(binned_values),
                                                )
        
        # normalization factor
        factor = np.sum(binned_values*np.diff(real_bins))
        yhat = factor*gamma.pdf(real_bins, 
                                fit_alpha, 
                                fit_loc, 
                                fit_beta,
                               )
        if (np.any(np.isnan(yhat))):
            continue     
            
        x = np.linspace(xmin, xmax, 1000)
        y = factor*gamma.pdf(x, 
                             fit_alpha, 
                             fit_loc, 
                             fit_beta)
        
        error = utils.fitter_meter(binned_values, yhat[:-1])
        
        # plotting 
        title = utils.create_title(d, name_id=-1)
        if MAKE_IMAGES:
            # create the canvas
            fig = plt.figure(figsize=(8,5))
            fig.suptitle(title)

            plt.hist(I, 
                     bins=bins, 
                     color=COLOR, 
                     # label=TYPE, 
                     density=False,
                    )
            plt.plot(x, 
                     y, 
                     linewidth=5, 
                     color='#66A5AD',
                    )   
            # vertical line for center
            plt.axvline(x=real_bins[np.argmax(yhat)], 
                        linestyle="--", 
                        linewidth=5, 
                        color='#66A5AD',
                       )

            # print("error: L1, L2", error)
            # print("peak center:", real_bins[np.argmax(yhat)])

            # reasonable adjustments to make the data look nicer
            plt.xlabel('intensity')
            plt.ylabel('# spots')

            info_text = "Total: " + str(I.shape[0]) + "\n" + "Peak: " +  str('%.2f' % real_bins[np.argmax(yhat)]) + "\n" + "L1: " + str('%.2f' % error[0]) + "\n" + "L2: " +  str('%.2f' % error[1]) 

            x_limits = [xmin, xmax]
            ymax = np.max(np.histogram(I, bins)[0])
            y_limits = [0, ymax]

            plt.text(x_limits[1] - (x_limits[1] - x_limits[0])*0.15, y_limits[1]*0.8, info_text, color='black', bbox=dict(facecolor='white', alpha=1))
            plt.xlim([xmin, xmax])
            
            # plt.savefig(os.path.join(folder_path, title + ".pdf"))
            plt.show()
            # plt.close()

        # save the peak values for further 
        center_set[title] = real_bins[np.argmax(yhat)]  
        folder_path = os.path.join(FOLDER, "histograms-2")

        os.makedirs(folder_path, exist_ok=True)
    except(RuntimeError, TypeError, ValueError):
        print("There was an exception but we\'ll fix it for you")
pbar.close()
# df_center = pd.DataFrame(list(center_set.items()), columns=['filename', 'center'])
# if (os.path.exists(center_path)):
#     df_center.to_csv(center_path, index=False, header=False, encoding='utf-8', mode = 'a')
# else:
#     df_center.to_csv(center_path, index=False, header=True, encoding='utf-8', mode = 'w' )
#     print (df_center)
# Out:
# Processing: 13399 files
# HBox(children=(IntProgress(value=0, max=13399), HTML(value='')))
# /Users/kkolyva/pretty-graphs/up-to-date/utils.py:6: UserWarning: loadtxt: Empty input file: "/Users/kkolyva/Downloads/2019-10-01-all/csv/C0-N2_1643_cropped_3978.csv"
#   data = np.loadtxt(file_path, delimiter = '\t', skiprows=skiprows_)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:410: RuntimeWarning: invalid value encountered in double_scalars
#   return m3 / np.power(m2, 1.5)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: divide by zero encountered in long_scalars
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:569: RuntimeWarning: invalid value encountered in subtract
#   if (numpy.max(numpy.ravel(numpy.abs(sim[1:] - sim[0]))) <= xatol and
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:574: RuntimeWarning: invalid value encountered in subtract
#   xr = (1 + rho) * xbar - rho * sim[-1]
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:616: RuntimeWarning: invalid value encountered in subtract
#   sim[j] = sim[0] + sigma * (sim[j] - sim[0])
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in greater_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in less_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: divide by zero encountered in long_scalars
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:569: RuntimeWarning: invalid value encountered in subtract
#   if (numpy.max(numpy.ravel(numpy.abs(sim[1:] - sim[0]))) <= xatol and
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:574: RuntimeWarning: invalid value encountered in subtract
#   xr = (1 + rho) * xbar - rho * sim[-1]
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:616: RuntimeWarning: invalid value encountered in subtract
#   sim[j] = sim[0] + sigma * (sim[j] - sim[0])
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in greater_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in less_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: divide by zero encountered in long_scalars
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:569: RuntimeWarning: invalid value encountered in subtract
#   if (numpy.max(numpy.ravel(numpy.abs(sim[1:] - sim[0]))) <= xatol and
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:574: RuntimeWarning: invalid value encountered in subtract
#   xr = (1 + rho) * xbar - rho * sim[-1]
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:616: RuntimeWarning: invalid value encountered in subtract
#   sim[j] = sim[0] + sigma * (sim[j] - sim[0])
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in greater_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in less_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/pretty-graphs/up-to-date/utils.py:6: UserWarning: loadtxt: Empty input file: "/Users/kkolyva/Downloads/2019-10-01-all/csv/C0-CB428_40_cropped_4083.csv"
#   data = np.loadtxt(file_path, delimiter = '\t', skiprows=skiprows_)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:410: RuntimeWarning: invalid value encountered in double_scalars
#   return m3 / np.power(m2, 1.5)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/kkolyva/pretty-graphs/up-to-date/utils.py:6: UserWarning: loadtxt: Empty input file: "/Users/kkolyva/Downloads/2019-10-01-all/csv/C0-CB428_152_cropped_4207.csv"
#   data = np.loadtxt(file_path, delimiter = '\t', skiprows=skiprows_)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:410: RuntimeWarning: invalid value encountered in double_scalars
#   return m3 / np.power(m2, 1.5)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: divide by zero encountered in long_scalars
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:569: RuntimeWarning: invalid value encountered in subtract
#   if (numpy.max(numpy.ravel(numpy.abs(sim[1:] - sim[0]))) <= xatol and
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:574: RuntimeWarning: invalid value encountered in subtract
#   xr = (1 + rho) * xbar - rho * sim[-1]
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:616: RuntimeWarning: invalid value encountered in subtract
#   sim[j] = sim[0] + sigma * (sim[j] - sim[0])
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in greater_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in less_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: divide by zero encountered in long_scalars
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:569: RuntimeWarning: invalid value encountered in subtract
#   if (numpy.max(numpy.ravel(numpy.abs(sim[1:] - sim[0]))) <= xatol and
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:574: RuntimeWarning: invalid value encountered in subtract
#   xr = (1 + rho) * xbar - rho * sim[-1]
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:616: RuntimeWarning: invalid value encountered in subtract
#   sim[j] = sim[0] + sigma * (sim[j] - sim[0])
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in greater_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in less_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: divide by zero encountered in long_scalars
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:569: RuntimeWarning: invalid value encountered in subtract
#   if (numpy.max(numpy.ravel(numpy.abs(sim[1:] - sim[0]))) <= xatol and
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:574: RuntimeWarning: invalid value encountered in subtract
#   xr = (1 + rho) * xbar - rho * sim[-1]
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py:616: RuntimeWarning: invalid value encountered in subtract
#   sim[j] = sim[0] + sigma * (sim[j] - sim[0])
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in greater_equal
#   return (self.a <= x) & (x <= self.b)
# /Users/kkolyva/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:874: RuntimeWarning: invalid value encountered in less_equal
#   return (self.a <= x) & (x <= self.b)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-a91d3fc259dc> in <module>
#      26         fit_alpha, fit_loc, fit_beta = gamma.fit(I,
#      27                                                  loc=use_median/2,
# ---> 28                                                  scale=1/np.max(binned_values),
#      29                                                 )
#      30
#
# ~/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_continuous_distns.py in fit(self, data, *args, **kwds)
#    2560         if floc is None:
#    2561             # loc is not fixed.  Use the default fit method.
# -> 2562             return super(gamma_gen, self).fit(data, *args, **kwds)
#    2563
#    2564         # Special case: loc is fixed.
#
# ~/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py in fit(self, data, *args, **kwds)
#    2218             raise TypeError("Unknown arguments: %s." % kwds)
#    2219
# -> 2220         vals = optimizer(func, x0, args=(ravel(data),), disp=0)
#    2221         if restore is not None:
#    2222             vals = restore(args, vals)
#
# ~/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     414             'initial_simplex': initial_simplex}
#     415
# --> 416     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     417     if full_output:
#     418         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~/anaconda3/envs/pretty-graphs/lib/python3.6/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     567
#     568     while (fcalls[0] < maxfun and iterations < maxiter):
# --> 569         if (numpy.max(numpy.ravel(numpy.abs(sim[1:] - sim[0]))) <= xatol and
#     570                 numpy.max(numpy.abs(fsim[0] - fsim[1:])) <= fatol):
#     571             break
#
# KeyboardInterrupt:

# %%
TYPE

# %%
PARAMS
